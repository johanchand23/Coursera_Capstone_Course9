# %% [markdown]
# # Determine the area for a modern Japanese Restaurant franchise in Singapore

# %% [markdown]
# ## Introduction

# %% [markdown]
# Japanese cuisine encompasses the regional and traditional foods of Japan, which have developed through centuries of social and economic changes. Japanese food is hands-down the most popular cuisine in Singapore.

# %% [markdown]
# ## Problem

# %% [markdown]
# Propose a research for the best Area/ District in Singapore to open a new Japanese Restaurant franchise.

# %% [markdown]
# ## Tools Requirements

# %% [markdown]
# - Jupyter Notebooks
# - IBM Watson Account
# - Singapore Data Sets
# - Foursquare API
